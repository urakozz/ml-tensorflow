# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('Sample data (rev dict)', [reverse_dictionary[i] for i in data[:10]])
print('Backward check:  Words',words[:10])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3134, 46, 59, 156]
# Sample data (rev dict) ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# Backward check:  Words ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      #print(i, target, buffer)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(1, 2), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 1 and skip_window = 2:
#     batch: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     labels: ['anarchism', 'of', 'abuse', 'a', 'used', 'of', 'abuse', 'working']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  print("embeddings", embeddings.get_shape().as_list())
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print("embed", embed.get_shape().as_list())
  # Compute the softmax loss, using a sample of the negative labels each time.
  # logits = tf.matmul(embed, softmax_weights) + softmax_biases
  # loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, train_labels)) 
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  print("norm", norm.get_shape().as_list())
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  print("valid e", valid_embeddings.get_shape().as_list())
  print("normalized_embeddings", normalized_embeddings.get_shape().as_list())
  print("transpose normalized_embeddings", tf.transpose(normalized_embeddings).get_shape().as_list())
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print("similarity", similarity.get_shape().as_list())
# Out:
# embeddings [50000, 128]
# embed [128, 128]
# norm [50000, 1]
# valid e [16, 128]
# normalized_embeddings [50000, 128]
# transpose normalized_embeddings [128, 50000]
# similarity [16, 50000]

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
 
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.112797
# Nearest to up: behaves, dianic, councilor, metamorphism, nuclei, malevolent, hallmarks, bakunin,
# Nearest to see: blames, shiki, nootka, whimsical, dangling, edifices, lawrencium, seebeck,
# Nearest to th: cpl, reese, beatles, vilna, saviola, adolf, sanjay, mort,
# Nearest to known: rep, steinmetz, infertility, cuc, steric, edmonton, hypothyroidism, russ,
# Nearest to will: agreement, luckily, pharyngeal, encodings, hypergeometric, harwood, selangor, hutcheson,
# Nearest to other: hijacked, motherland, pradesh, augment, stool, berkeley, gunmen, enz,
# Nearest to while: servicemen, documentary, genomics, rosalind, gravely, pamphilus, courted, rollins,
# Nearest to may: shikai, kellermann, remarks, madrigal, svenska, scales, criswell, soften,
# Nearest to not: persona, kirby, versa, groupoids, adverse, embraced, prokaryotes, stout,
# Nearest to it: runner, polygamy, malayalam, reactant, connexion, orientation, allein, embryo,
# Nearest to many: montague, proudest, sympathy, milieu, view, seigenthaler, canidae, rattus,
# Nearest to if: breasts, souvenir, mears, resin, officials, katal, enforcers, exons,
# Nearest to some: maga, decree, cadet, foiled, memel, tentatively, reforestation, segr,
# Nearest to system: electrically, vc, asmara, lice, kathryn, ega, formalisms, fulfilled,
# Nearest to has: kanji, gaps, errors, healer, dunk, rebound, undergoes, bhumi,
# Nearest to used: ferreira, dietrich, hofmann, skillfully, rajah, wisest, finale, olfactory,
# Average loss at step 2000: 4.359968
# Average loss at step 4000: 3.848912
# Average loss at step 6000: 3.778054
# Average loss at step 8000: 3.671811
# Average loss at step 10000: 3.662009
# Nearest to up: councilor, behaves, quail, swans, dianic, bassoonist, hallmarks, solved,
# Nearest to see: blames, shiki, nucleons, drugs, slough, comforts, vilayet, whimsical,
# Nearest to th: cpl, four, adolf, vilna, reese, leans, beatles, enlisting,
# Nearest to known: used, well, infertility, edmonton, sayyaf, hypothyroidism, defer, ek,
# Nearest to will: would, can, agreement, may, latino, deut, polynesia, pharyngeal,
# Nearest to other: social, these, lcms, eventual, some, wayside, decades, hijacked,
# Nearest to while: andriessen, documentary, nuke, are, systematically, dissolving, tooth, rosalind,
# Nearest to may: can, could, would, will, byrne, should, detachable, ippon,
# Nearest to not: laughter, there, they, it, atmospheres, rica, now, to,
# Nearest to it: he, this, they, there, she, which, negated, onerous,
# Nearest to many: some, montague, milieu, groove, seclusion, markup, rattus, whatsoever,
# Nearest to if: since, mears, yr, factual, resin, aeroplanes, truk, cao,
# Nearest to some: many, reign, buchner, leonid, companies, other, foiled, gimp,
# Nearest to system: electrically, vc, asmara, mannerism, kathryn, athabasca, peaks, full,
# Nearest to has: had, was, have, is, repeatedly, apec, paws, wikiproject,
# Nearest to used: ferreira, exmouth, known, detachment, alef, dietrich, circulatory, kalat,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

# the same, just replaced batch with labels :)
def generate_batch_cbow(batch_size, skip_window):
    global data_index
    
    context_window = 2 * skip_window
    
    assert batch_size % context_window == 0
    # number of words around the target, will use all of then, no need skips
    
    num_labels = batch_size // context_window
   
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window... , target, skip_window... ]
    
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(num_labels):
        target = skip_window # buffer index to take (self)
        avoid = [target] # avoid self and already taken in budder
        
        for j in range(context_window):
            while target in avoid:
                target = random.randint(0, span -1) # find new random target from our window (span)
            avoid.append(target)
            
            labels[i*context_window + j, 0] = buffer[skip_window]
            batch[i*context_window + j] = buffer[target]
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    return batch, labels

batch, labels = generate_batch_cbow(8, 1)
print("batch", [reverse_dictionary[i] for i in batch])
print("labels",[reverse_dictionary[i] for i in labels.reshape(8)])
# Out:
# batch ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
# labels ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
 
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.771913
# Nearest to up: maxine, lair, continues, descendents, longhorn, transpose, enquiries, buffalo,
# Nearest to see: cognition, pew, wedded, alpaca, robotics, rds, pygmalion, hin,
# Nearest to th: hypocritical, warsaw, blockers, stump, viollet, sources, reconfigurable, embryology,
# Nearest to known: flag, skeleton, dividing, baumgarten, stwertka, gilchrist, relatively, segment,
# Nearest to will: foreseen, mortars, alia, keypad, angelina, osr, tasks, palaeologus,
# Nearest to other: amethyst, hallmarks, skilful, machen, hippo, combs, hispanics, snowmen,
# Nearest to while: artiodactyla, persona, feather, tantamount, matriculation, shaped, galactic, scotch,
# Nearest to may: jeroboam, charters, neman, irate, mahogany, frey, popped, airfoil,
# Nearest to not: emptied, funeral, fer, updates, fulltext, perry, eschewed, alyattes,
# Nearest to it: clockwork, eigenstates, dauphin, donaghy, markers, smoot, descriptive, entertainment,
# Nearest to many: preschool, vigorously, concerts, stickers, feyerabend, slapstick, butterfield, euclid,
# Nearest to if: hada, renounced, intake, boswell, ameliorate, kildall, sorel, montego,
# Nearest to some: tarot, vih, professed, mccarthyism, axial, registering, castel, eostre,
# Nearest to system: borgir, mispronounced, startup, ekaterina, fabrics, belknap, packard, shi,
# Nearest to has: lowball, cascade, transports, vocalist, darlington, asturias, tyrannical, tocantins,
# Nearest to used: sexagesimal, egyptologist, passy, tamer, prevention, acharya, slaughters, prosper,
# Average loss at step 2000: 4.354994
# Average loss at step 4000: 3.868749
# Average loss at step 6000: 3.785608
# Average loss at step 8000: 3.686115
# Average loss at step 10000: 3.613857
# Nearest to up: transpose, buffalo, unattested, beac, enquiries, overtaken, hijacked, ezek,
# Nearest to see: greenhouses, turbulent, seam, outlawing, shaikh, elsewhere, ksh, quartic,
# Nearest to th: warsaw, diode, reconfigurable, viollet, caenorhabditis, hypocritical, soliloquy, sources,
# Nearest to known: discarded, leh, cumont, factorizations, skeleton, ionia, look, zhejiang,
# Nearest to will: would, mortars, furigana, foreseen, hsv, epithets, fetch, intended,
# Nearest to other: amethyst, motivate, hippo, baryon, retaken, keypad, reactivity, brabham,
# Nearest to while: pizarro, discomfort, shaped, scrap, artiodactyla, propagandist, nynorsk, remission,
# Nearest to may: can, yogi, exponentiation, hartmann, reunited, might, prefects, sip,
# Nearest to not: styne, it, they, who, juan, converges, jafar, entrenched,
# Nearest to it: he, this, there, not, she, which, zodiac, also,
# Nearest to many: some, vigorously, creationists, preschool, patois, languages, butterfield, illusory,
# Nearest to if: trebizond, so, atheroma, horton, ameliorate, musicians, snap, caltech,
# Nearest to some: many, autographed, bryn, provisions, geographical, ciconiiformes, predominate, cassian,
# Nearest to system: mispronounced, startup, fabrics, borgir, songwriting, trigger, rural, worthless,
# Nearest to has: had, was, have, is, azeotrope, adopts, imitative, transports,
# Nearest to used: sexagesimal, tamer, egyptologist, democritus, soleil, prevention, vannevar, passy,
